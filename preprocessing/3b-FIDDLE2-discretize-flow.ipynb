# %%
import joblib
import pandas as pd
import numpy as np
import sparse
import json

# %% [markdown]
# ### Flow

# %%
df_time_series = joblib.load('sample_output/out_flow/sdf_time_series.joblib')
discretization_bins = json.load(open('metadata/out_flow/discretization.json', 'r'))
feature_names = json.load(open('metadata/out_flow/X_all.feature_names.json', 'r'))
len(discretization_bins)
# Out:
# 654

# %%
cols_useful = list(discretization_bins.keys())
df_time_series = df_time_series[cols_useful]

# %%
df_time_series
# Out:
# variable_name _307795_value _307796_value _307800_value _307799_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _307804_value _307806_value _307807_value _307808_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _307809_value _307811_value _307810_value _307812_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _307814_value _307815_value _307839_value _307816_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _307840_value _307842_value _307929_value _307930_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _307928_value _307925_value _307932_value _307933_value  \
# ID
# 90000-____0               0           NaN           NaN           NaN
# 90000-____1               5           NaN           NaN           NaN
# 90001-____0               2           NaN           NaN           NaN
#
# variable_name _307926_value _307962_value _307967_value _307968_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _307936_value _307971_value _307972_value _307969_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _307965_value _307973_value _307975_value _307974_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _307976_value _307978_value _307979_value _307980_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _307981_value _307982_value _307983_value _307984_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _307985_value _307986_value _307988_value _307989_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _307990_value _307991_value  ... _535637_value _535638_value  \
# ID                                         ...
# 90000-____0             NaN           NaN  ...           NaN           NaN
# 90000-____1             NaN           NaN  ...           NaN           NaN
# 90001-____0             NaN           NaN  ...           NaN           NaN
#
# variable_name _535639_value _535641_value _535642_value _535644_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _535645_value _655634_value _654071_value _662228_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _654072_value _654073_value _666387_value _654075_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _667597_value _666968_value _666388_value _668125_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _668126_value _668123_value _668127_value _668129_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _668128_value _668130_value _668131_value _668132_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _668133_value _668137_value _672573_value _668135_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _672574_value _672575_value _672576_value _672578_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _672579_value _673731_value _674330_value _674332_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _674331_value _674333_value _674336_value _674334_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _674335_value _676545_value _686397_value _676546_value  \
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# variable_name _689436_value _685863_value _690993_value _690305_value
# ID
# 90000-____0             NaN           NaN           NaN           NaN
# 90000-____1             NaN           NaN           NaN           NaN
# 90001-____0             NaN           NaN           NaN           NaN
#
# [3 rows x 654 columns]

# %%
ddf = df_time_series.sparse.to_dense()

# %%
from steps_2 import *
from helpers import *

# %%
df = ddf

# %% [raw]
# df_by_cols = [df[col] for col in df.columns]

# %%
pool = multiprocessing.Pool(multiprocessing.cpu_count())
out_0 = list(tqdm(pool.imap_unordered(
    smart_qcut_bins,
    [(df[col], discretization_bins[col]) for col in df.columns]), total=len(df.columns)
))
cols_data, dis_bins = zip(*out_0)
out = list(tqdm(pool.imap_unordered(dummify, cols_data), total=len(df.columns)
))
pool.close()
pool.join()
# Out:
# 100%|██████████| 654/654 [00:00<00:00, 962.32it/s]
# 100%|██████████| 654/654 [00:00<00:00, 1013.94it/s]

# %% [raw]
# out_0 = [smart_qcut_bins(x, discretization_bins[x.name]) for x in tqdm(df_by_cols)]
# cols_data, dis_bins = zip(*out_0)
# out = [dummify(z) for z in tqdm(cols_data)]

# %% [raw]
# time_invariant_features = pd.concat(out, axis=1).sort_index(axis=1)
# feature_names_all = time_invariant_features.columns.values
# sdf = time_invariant_features.astype(pd.SparseDtype(int, fill_value=0))
# s_ = sparse.COO(sdf.sparse.to_coo())

# %%
df_features = pd.concat(out, axis=1).sort_index(axis=1)

# %%
# Drop any values='missing' for now
df_features = df_features.loc[:, [col for col in df_features.columns if 'missing' not in col]]

# %%
# Make sure same features
set(df_features.columns) <= set(feature_names)
# Out:
# True

# %%
set(df_features.columns) - set(feature_names)
# Out:
# set()

# %%
df_features = df_features.reindex(columns=feature_names, fill_value=0)

# %%
df_features
# Out:
#              _307795_value_(0.162, 63.899]  _307795_value_(105.687, 333.696]  \
# ID
# 90000-____0                              0                                 0
# 90000-____1                              0                                 0
# 90001-____0                              0                                 0
#
#              _307795_value_(63.899, 76.699]  _307795_value_(76.699, 88.768]  \
# ID
# 90000-____0                               0                               0
# 90000-____1                               0                               0
# 90001-____0                               0                               0
#
#              _307795_value_(88.768, 105.687]  _307796_value_(160.02, 167.64]  \
# ID
# 90000-____0                                0                               0
# 90000-____1                                0                               0
# 90001-____0                                0                               0
#
#              _307796_value_(167.64, 172.72]  _307796_value_(172.72, 180.34]  \
# ID
# 90000-____0                               0                               0
# 90000-____1                               0                               0
# 90001-____0                               0                               0
#
#              _307796_value_(180.34, 276.86]  _307796_value_(5.0, 160.02]  \
# ID
# 90000-____0                               0                            0
# 90000-____1                               0                            0
# 90001-____0                               0                            0
#
#              _307799_value_(-87.971, 52.4]  _307799_value_(52.4, 59.3]  \
# ID
# 90000-____0                              0                           0
# 90000-____1                              0                           0
# 90001-____0                              0                           0
#
#              _307799_value_(59.3, 63.9]  _307799_value_(63.9, 70.8]  \
# ID
# 90000-____0                           0                           0
# 90000-____1                           0                           0
# 90001-____0                           0                           0
#
#              _307799_value_(70.8, 158.2]  _307800_value_(-83.471, 56.9]  \
# ID
# 90000-____0                            0                              0
# 90000-____1                            0                              0
# 90001-____0                            0                              0
#
#              _307800_value_(56.9, 63.8]  _307800_value_(63.8, 68.4]  \
# ID
# 90000-____0                           0                           0
# 90000-____1                           0                           0
# 90001-____0                           0                           0
#
#              _307800_value_(68.4, 75.3]  _307800_value_(75.3, 162.7]  \
# ID
# 90000-____0                           0                            0
# 90000-____1                           0                            0
# 90001-____0                           0                            0
#
#              _307804_value_(-0.001, 64.0]  _307804_value_(106.0, 334.0]  \
# ID
# 90000-____0                             0                             0
# 90000-____1                             0                             0
# 90001-____0                             0                             0
#
#              _307804_value_(64.0, 77.0]  _307804_value_(77.0, 89.0]  \
# ID
# 90000-____0                           0                           0
# 90000-____1                           0                           0
# 90001-____0                           0                           0
#
#              _307804_value_(89.0, 106.0]  _307806_value_(-0.001, 192.0]  \
# ID
# 90000-____0                            0                              0
# 90000-____1                            0                              0
# 90001-____0                            0                              0
#
#              _307806_value_(192.0, 230.0]  _307806_value_(230.0, 266.0]  \
# ID
# 90000-____0                             0                             0
# 90000-____1                             0                             0
# 90001-____0                             0                             0
#
#              _307806_value_(266.0, 317.0]  _307806_value_(317.0, 1001.0]  \
# ID
# 90000-____0                             0                              0
# 90000-____1                             0                              0
# 90001-____0                             0                              0
#
#              _307807_value_(-123.20100000000001, 73.4]  \
# ID
# 90000-____0                                          0
# 90000-____1                                          0
# 90001-____0                                          0
#
#              _307807_value_(105.4, 227.8]  _307807_value_(73.4, 83.0]  \
# ID
# 90000-____0                             0                           0
# 90000-____1                             0                           0
# 90001-____0                             0                           0
#
#              _307807_value_(83.0, 95.8]  _307807_value_(95.8, 105.4]  \
# ID
# 90000-____0                           0                            0
# 90000-____1                           0                            0
# 90001-____0                           0                            0
#
#              _307808_value_(1352.39, 1623.29]  \
# ID
# 90000-____0                                 0
# 90000-____1                                 0
# 90001-____0                                 0
#
#              _307808_value_(1623.29, 1878.72]  \
# ID
# 90000-____0                                 0
# 90000-____1                                 0
# 90001-____0                                 0
#
#              _307808_value_(1878.72, 2236.8]  _307808_value_(2236.8, 7062.48]  \
# ID
# 90000-____0                                0                                0
# 90000-____1                                0                                0
# 90001-____0                                0                                0
#
#              _307808_value_(3.439, 1352.39]  _307809_value_(-0.001, 10570.3]  \
# ID
# 90000-____0                               0                                0
# 90000-____1                               0                                0
# 90001-____0                               0                                0
#
#              _307810_value_(-87.971, 52.4]  _307810_value_(52.4, 59.3]  \
# ID
# 90000-____0                              0                           0
# 90000-____1                              0                           0
# 90001-____0                              0                           0
#
#              _307810_value_(59.3, 68.4]  _307810_value_(68.4, 75.3]  \
# ID
# 90000-____0                           0                           0
# 90000-____1                           0                           0
# 90001-____0                           0                           0
#
#              _307810_value_(75.3, 162.7]  _307811_value_(2.399, 22.7]  \
# ID
# 90000-____0                            0                            0
# 90000-____1                            0                            0
# 90001-____0                            0                            0
#
#              _307811_value_(22.7, 26.3]  _307811_value_(26.3, 29.9]  \
# ID
# 90000-____0                           0                           0
# 90000-____1                           0                           0
# 90001-____0                           0                           0
#
#              _307811_value_(29.9, 35.2]  ...  _674332_value_(7.7, 10.2]  \
# ID                                       ...
# 90000-____0                           0  ...                          0
# 90000-____1                           0  ...                          0
# 90001-____0                           0  ...                          0
#
#              _674333_value_(20.999, 22.0]  _674333_value_(22.0, 24.0]  \
# ID
# 90000-____0                             0                           0
# 90000-____1                             0                           0
# 90001-____0                             0                           0
#
#              _674333_value_(24.0, 26.0]  _674333_value_(26.0, 40.0]  \
# ID
# 90000-____0                           0                           0
# 90000-____1                           0                           0
# 90001-____0                           0                           0
#
#              _674334_value_(103.0, 110.0]  _674334_value_(110.0, 176.0]  \
# ID
# 90000-____0                             0                             0
# 90000-____1                             0                             0
# 90001-____0                             0                             0
#
#              _674334_value_(90.999, 94.0]  _674334_value_(94.0, 98.0]  \
# ID
# 90000-____0                             0                           0
# 90000-____1                             0                           0
# 90001-____0                             0                           0
#
#              _674334_value_(98.0, 103.0]  _674335_value_(67.999, 78.8]  \
# ID
# 90000-____0                            0                             0
# 90000-____1                            0                             0
# 90001-____0                            0                             0
#
#              _674335_value_(78.8, 83.0]  _674335_value_(83.0, 85.0]  \
# ID
# 90000-____0                           0                           0
# 90000-____1                           0                           0
# 90001-____0                           0                           0
#
#              _674335_value_(85.0, 88.0]  _674335_value_(88.0, 89.0]  \
# ID
# 90000-____0                           0                           0
# 90000-____1                           0                           0
# 90001-____0                           0                           0
#
#              _674336_value_High  _674336_value_Low  _674336_value_Medium  \
# ID
# 90000-____0                   0                  0                     0
# 90000-____1                   0                  0                     0
# 90001-____0                   0                  0                     0
#
#              _674336_value_No Alert  _676545_value_(64075.999, 65196.0]  \
# ID
# 90000-____0                       0                                   0
# 90000-____1                       0                                   0
# 90001-____0                       0                                   0
#
#              _676545_value_(65196.0, 65242.0]  \
# ID
# 90000-____0                                 0
# 90000-____1                                 0
# 90001-____0                                 0
#
#              _676545_value_(65242.0, 65289.0]  \
# ID
# 90000-____0                                 0
# 90000-____1                                 0
# 90001-____0                                 0
#
#              _676545_value_(65289.0, 65340.0]  \
# ID
# 90000-____0                                 0
# 90000-____1                                 0
# 90001-____0                                 0
#
#              _676545_value_(65340.0, 98096.0]  \
# ID
# 90000-____0                                 0
# 90000-____1                                 0
# 90001-____0                                 0
#
#              _676546_value_(64600.999, 65196.0]  \
# ID
# 90000-____0                                   0
# 90000-____1                                   0
# 90001-____0                                   0
#
#              _676546_value_(65196.0, 65241.0]  \
# ID
# 90000-____0                                 0
# 90000-____1                                 0
# 90001-____0                                 0
#
#              _676546_value_(65241.0, 65289.0]  \
# ID
# 90000-____0                                 0
# 90000-____1                                 0
# 90001-____0                                 0
#
#              _676546_value_(65289.0, 65336.0]  \
# ID
# 90000-____0                                 0
# 90000-____1                                 0
# 90001-____0                                 0
#
#              _676546_value_(65336.0, 65428.0]  _685863_value_(-0.001, 0.4]  \
# ID
# 90000-____0                                 0                            0
# 90000-____1                                 0                            0
# 90001-____0                                 0                            0
#
#              _685863_value_(0.4, 0.8]  _685863_value_(0.8, 1.5]  \
# ID
# 90000-____0                         0                         0
# 90000-____1                         0                         0
# 90001-____0                         0                         0
#
#              _685863_value_(1.5, 3.0]  _685863_value_(3.0, 65.0]  \
# ID
# 90000-____0                         0                          0
# 90000-____1                         0                          0
# 90001-____0                         0                          0
#
#              _686397_value_Yes  _689436_value_Agitation/sedation  \
# ID
# 90000-____0                  0                                 0
# 90000-____1                  0                                 0
# 90001-____0                  0                                 0
#
#              _689436_value_Air hunger/short of breath  \
# ID
# 90000-____0                                         0
# 90000-____1                                         0
# 90001-____0                                         0
#
#              _689436_value_Anticipated pain  _689436_value_Other non-pain  \
# ID
# 90000-____0                               0                             0
# 90000-____1                               0                             0
# 90001-____0                               0                             0
#
#              _689436_value_PRN pain medication  _689436_value_Pain  \
# ID
# 90000-____0                                  0                   0
# 90000-____1                                  0                   0
# 90001-____0                                  0                   0
#
#              _689436_value_Scheduled pain medication  \
# ID
# 90000-____0                                        0
# 90000-____1                                        0
# 90001-____0                                        0
#
#              _689436_value_Ventilator dyssynchrony  \
# ID
# 90000-____0                                      0
# 90000-____1                                      0
# 90001-____0                                      0
#
#              _690305_value_(-0.001, 0.4]  _690305_value_(0.4, 0.83]  \
# ID
# 90000-____0                            0                          0
# 90000-____1                            0                          0
# 90001-____0                            0                          0
#
#              _690305_value_(0.83, 1.0]  _690993_value_High Alert  \
# ID
# 90000-____0                          0                         0
# 90000-____1                          0                         0
# 90001-____0                          0                         0
#
#              _690993_value_Low Alert  _690993_value_Medium Alert  \
# ID
# 90000-____0                        0                           0
# 90000-____1                        0                           0
# 90001-____0                        0                           0
#
#              _690993_value_No Alert
# ID
# 90000-____0                       0
# 90000-____1                       0
# 90001-____0                       0
#
# [3 rows x 2703 columns]

# %%
sdf = df_features.astype(pd.SparseDtype(int, fill_value=0))
X_all = sparse.COO(sdf.sparse.to_coo())

# %%
sparse.save_npz('sample_output/out_flow/X_all.npz', X_all)
df_time_series[[]].to_csv('sample_output/out_flow/X_all.IDs.csv')

# %%
X_all.density
# Out:
# 0.0003699593044765076
