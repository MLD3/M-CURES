# %%
import joblib
import pandas as pd
import numpy as np
import sparse
import json

# %% [markdown]
# ### Labs

# %%
df_time_series = joblib.load('sample_output/out_labs/sdf.joblib')
discretization_bins = json.load(open('metadata/out_labs/discretization.json', 'r'))
feature_names = json.load(open('metadata/out_labs/X_all.feature_names.json', 'r'))
len(discretization_bins)
# Out:
# 2060

# %%
cols_useful = list(discretization_bins.keys())

# %%
df_time_series = df_time_series[cols_useful]

# %%
df_time_series
# Out:
# variable_name 122540_hilonormal_flag_value 122540_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 142414_hilonormal_flag_value 142414_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 142647_hilonormal_flag_value 142647_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 142945_hilonormal_flag_value 142945_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 143289_hilonormal_flag_value 143289_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 143290_hilonormal_flag_value 143290_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 144406_hilonormal_flag_value 144406_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 144409_hilonormal_flag_value 144409_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 144410_hilonormal_flag_value 144410_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 144411_hilonormal_flag_value 144411_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 145435_hilonormal_flag_value 145435_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 149157_hilonormal_flag_value 149157_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 149923_hilonormal_flag_value 149923_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 150017_hilonormal_flag_value 150017_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 151598_hilonormal_flag_value 152906_hilonormal_flag_value  \
# ID
# 90000-____0                            NaN                          NaN
# 90001-____0                            NaN                          NaN
#
# variable_name 151598_value_value 152906_value_value  \
# ID
# 90000-____0                  NaN                NaN
# 90001-____0                  NaN                NaN
#
# variable_name 153239_hilonormal_flag_value 153239_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 153240_hilonormal_flag_value 153240_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 155437_hilonormal_flag_value 155437_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 209760_hilonormal_flag_value 209760_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 216193_hilonormal_flag_value 216193_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 328952_hilonormal_flag_value 328952_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 329696_hilonormal_flag_value 329696_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 329697_hilonormal_flag_value 329697_value_value  \
# ID
# 90000-____0                            NaN                NaN
# 90001-____0                            NaN                NaN
#
# variable_name 329698_hilonormal_flag_value 329698_value_value  ...  \
# ID                                                             ...
# 90000-____0                            NaN                NaN  ...
# 90001-____0                            NaN                NaN  ...
#
# variable_name 91804_hilonormal_flag_value 91804_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 92164_hilonormal_flag_value 92232_hilonormal_flag_value  \
# ID
# 90000-____0                           NaN                         NaN
# 90001-____0                           NaN                         NaN
#
# variable_name 92164_value_value 92381_hilonormal_flag_value 92232_value_value  \
# ID
# 90000-____0                 NaN                         NaN               NaN
# 90001-____0                 NaN                         NaN               NaN
#
# variable_name 92381_value_value 92501_hilonormal_flag_value 92501_value_value  \
# ID
# 90000-____0                 NaN                         NaN               NaN
# 90001-____0                 NaN                         NaN               NaN
#
# variable_name 92502_hilonormal_flag_value 92502_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 92504_hilonormal_flag_value 92504_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 92505_hilonormal_flag_value 92505_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 92770_hilonormal_flag_value 92770_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 92772_hilonormal_flag_value 92772_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 92951_hilonormal_flag_value 92951_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 92952_hilonormal_flag_value 92952_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 93815_hilonormal_flag_value 93815_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 93817_hilonormal_flag_value 93817_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 93818_hilonormal_flag_value 93818_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 94464_hilonormal_flag_value 94464_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 94514_hilonormal_flag_value 94514_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 94515_hilonormal_flag_value 94515_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 94544_hilonormal_flag_value 94544_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 94973_hilonormal_flag_value 94973_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 95056_hilonormal_flag_value 95056_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 95123_hilonormal_flag_value 95123_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 95558_hilonormal_flag_value 95558_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 95814_hilonormal_flag_value 95814_value_value  \
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# variable_name 96087_hilonormal_flag_value 96087_value_value
# ID
# 90000-____0                           NaN               NaN
# 90001-____0                           NaN               NaN
#
# [2 rows x 2060 columns]

# %%
ddf = df_time_series.sparse.to_dense()

# %%
from steps_2 import *
from helpers import *

# %%
df = ddf

# %%
df_by_cols = [df[col] for col in df.columns]

# %%
pool = multiprocessing.Pool(multiprocessing.cpu_count())
out_0 = list(tqdm(pool.imap_unordered(
    smart_qcut_bins,
    [(df[col], discretization_bins[col]) for col in df.columns]), total=len(df.columns)
))
cols_data, dis_bins = zip(*out_0)
out = list(tqdm(pool.imap_unordered(dummify, cols_data), total=len(df.columns)
))
pool.close()
pool.join()
# Out:
# 100%|██████████| 2060/2060 [00:02<00:00, 957.26it/s]
# 100%|██████████| 2060/2060 [00:01<00:00, 1212.62it/s]

# %% [raw]
# out_0 = [smart_qcut_bins(x, discretization_bins[x.name]) for x in tqdm(df_by_cols)]
# cols_data, dis_bins = zip(*out_0)
# out = [dummify(z) for z in tqdm(cols_data)]

# %% [raw]
# time_invariant_features = pd.concat(out, axis=1).sort_index(axis=1)
# feature_names_all = time_invariant_features.columns.values
# sdf = time_invariant_features.astype(pd.SparseDtype(int, fill_value=0))
# s_ = sparse.COO(sdf.sparse.to_coo())

# %%
df_features = pd.concat(out, axis=1).sort_index(axis=1)

# %%
# Drop any values='missing' for now
df_features = df_features.loc[:, [col for col in df_features.columns if 'missing' not in col]]

# %%
# Check same features
set(df_features.columns) <= set(feature_names)
# Out:
# False

# %%
df_features = df_features.reindex(columns=feature_names, fill_value=0)

# %%
df_features
# Out:
#              122540_hilonormal_flag_value_N  122540_value_value_ DNR  \
# ID
# 90000-____0                               0                        0
# 90001-____0                               0                        0
#
#              142414_hilonormal_flag_value_N  142414_value_value_ <=0.015  \
# ID
# 90000-____0                               0                            0
# 90001-____0                               0                            0
#
#              142414_value_value_ >16  \
# ID
# 90000-____0                        0
# 90001-____0                        0
#
#              142414_value_value_(0.028999999999999998, 0.06]  \
# ID
# 90000-____0                                                0
# 90001-____0                                                0
#
#              142647_hilonormal_flag_value_N  142647_value_value_ DNR  \
# ID
# 90000-____0                               0                        0
# 90001-____0                               0                        0
#
#              142945_hilonormal_flag_value_I  142945_hilonormal_flag_value_R  \
# ID
# 90000-____0                               0                               0
# 90001-____0                               0                               0
#
#              142945_hilonormal_flag_value_S  142945_value_value_   \
# ID
# 90000-____0                               0                     0
# 90001-____0                               0                     0
#
#              142945_value_value_ <=16  142945_value_value_ >64  \
# ID
# 90000-____0                         0                        0
# 90001-____0                         0                        0
#
#              142945_value_value_32.0  142945_value_value_64.0  \
# ID
# 90000-____0                        0                        0
# 90001-____0                        0                        0
#
#              143289_hilonormal_flag_value_I  143289_hilonormal_flag_value_N  \
# ID
# 90000-____0                               0                               0
# 90001-____0                               0                               0
#
#              143289_hilonormal_flag_value_R  143289_hilonormal_flag_value_S  \
# ID
# 90000-____0                               0                               0
# 90001-____0                               0                               0
#
#              143289_value_value_ <=0.25  143289_value_value_ >2  \
# ID
# 90000-____0                           0                       0
# 90001-____0                           0                       0
#
#              143289_value_value_1.0  143289_value_value_2.0  \
# ID
# 90000-____0                       0                       0
# 90001-____0                       0                       0
#
#              143290_hilonormal_flag_value_I  143290_hilonormal_flag_value_N  \
# ID
# 90000-____0                               0                               0
# 90001-____0                               0                               0
#
#              143290_hilonormal_flag_value_R  143290_hilonormal_flag_value_S  \
# ID
# 90000-____0                               0                               0
# 90001-____0                               0                               0
#
#              143290_value_value_   143290_value_value_ <=0.5  \
# ID
# 90000-____0                     0                          0
# 90001-____0                     0                          0
#
#              143290_value_value_ <=4  143290_value_value_ >16  \
# ID
# 90000-____0                        0                        0
# 90001-____0                        0                        0
#
#              143290_value_value_ >2  143290_value_value_(0.999, 8.0]  \
# ID
# 90000-____0                       0                                0
# 90001-____0                       0                                0
#
#              143290_value_value_(8.0, 16.0]  144406_hilonormal_flag_value_I  \
# ID
# 90000-____0                               0                               0
# 90001-____0                               0                               0
#
#              144406_hilonormal_flag_value_N  144406_hilonormal_flag_value_S  \
# ID
# 90000-____0                               0                               0
# 90001-____0                               0                               0
#
#              144406_value_value_ <=2  144406_value_value_4.0  \
# ID
# 90000-____0                        0                       0
# 90001-____0                        0                       0
#
#              144406_value_value_8.0  144409_hilonormal_flag_value_I  \
# ID
# 90000-____0                       0                               0
# 90001-____0                       0                               0
#
#              144409_hilonormal_flag_value_N  144409_hilonormal_flag_value_R  \
# ID
# 90000-____0                               0                               0
# 90001-____0                               0                               0
#
#              144409_hilonormal_flag_value_S  144409_value_value_ <=0.015  \
# ID
# 90000-____0                               0                            0
# 90001-____0                               0                            0
#
#              144409_value_value_ >8  \
# ID
# 90000-____0                       0
# 90001-____0                       0
#
#              144409_value_value_(0.028999999999999998, 0.06]  \
# ID
# 90000-____0                                                0
# 90001-____0                                                0
#
#              144409_value_value_(0.06, 0.12]  144410_hilonormal_flag_value_I  \
# ID
# 90000-____0                                0                               0
# 90001-____0                                0                               0
#
#              ...  92951_hilonormal_flag_value_N  92951_value_value_ DNR  \
# ID           ...
# 90000-____0  ...                              0                       0
# 90001-____0  ...                              0                       0
#
#              92952_hilonormal_flag_value_N  92952_value_value_   \
# ID
# 90000-____0                              0                    0
# 90001-____0                              0                    0
#
#              93815_hilonormal_flag_value_N  93815_value_value_ SEE BELOW  \
# ID
# 90000-____0                              0                             0
# 90001-____0                              0                             0
#
#              93815_value_value_ See Comment  93815_value_value_ See comment  \
# ID
# 90000-____0                               0                               0
# 90001-____0                               0                               0
#
#              93817_hilonormal_flag_value_HAZY  93817_hilonormal_flag_value_N  \
# ID
# 90000-____0                                 0                              0
# 90001-____0                                 0                              0
#
#              93817_value_value_(10.999, 13.0]  93817_value_value_(13.0, 15.0]  \
# ID
# 90000-____0                                 0                               0
# 90001-____0                                 0                               0
#
#              93817_value_value_(15.0, 18.0]  93817_value_value_(18.0, 20.0]  \
# ID
# 90000-____0                               0                               0
# 90001-____0                               0                               0
#
#              93817_value_value_(20.0, 33.0]  93818_hilonormal_flag_value_N  \
# ID
# 90000-____0                               0                              0
# 90001-____0                               0                              0
#
#              93818_value_value_(11.999, 14.0]  93818_value_value_(14.0, 17.0]  \
# ID
# 90000-____0                                 0                               0
# 90001-____0                                 0                               0
#
#              93818_value_value_(17.0, 18.0]  93818_value_value_(18.0, 19.0]  \
# ID
# 90000-____0                               0                               0
# 90001-____0                               0                               0
#
#              93818_value_value_(19.0, 21.0]  94464_hilonormal_flag_value_A  \
# ID
# 90000-____0                               0                              0
# 90001-____0                               0                              0
#
#              94464_hilonormal_flag_value_N  94464_value_value_ see comment  \
# ID
# 90000-____0                              0                               0
# 90001-____0                              0                               0
#
#              94514_hilonormal_flag_value_A  94514_value_value_ Present  \
# ID
# 90000-____0                              0                           0
# 90001-____0                              0                           0
#
#              94515_hilonormal_flag_value_N  94515_value_value_ SEE BELOW  \
# ID
# 90000-____0                              0                             0
# 90001-____0                              0                             0
#
#              94515_value_value_(0.999, 21.0]  94515_value_value_(21.0, 33.0]  \
# ID
# 90000-____0                                0                               0
# 90001-____0                                0                               0
#
#              94515_value_value_(33.0, 49.0]  94544_hilonormal_flag_value_A  \
# ID
# 90000-____0                               0                              0
# 90001-____0                               0                              0
#
#              94544_value_value_ Present  94973_hilonormal_flag_value_N  \
# ID
# 90000-____0                           0                              0
# 90001-____0                           0                              0
#
#              94973_value_value_ <=0.008  94973_value_value_ >16  \
# ID
# 90000-____0                           0                       0
# 90001-____0                           0                       0
#
#              94973_value_value_ >8  \
# ID
# 90000-____0                      0
# 90001-____0                      0
#
#              94973_value_value_(0.013999999999999999, 0.03]  \
# ID
# 90000-____0                                               0
# 90001-____0                                               0
#
#              95056_hilonormal_flag_value_N  95056_value_value_ Present  \
# ID
# 90000-____0                              0                           0
# 90001-____0                              0                           0
#
#              95123_hilonormal_flag_value_N  95123_value_value_   \
# ID
# 90000-____0                              0                    0
# 90001-____0                              0                    0
#
#              95558_hilonormal_flag_value_N  95814_hilonormal_flag_value_A  \
# ID
# 90000-____0                              0                              0
# 90001-____0                              0                              0
#
#              95814_hilonormal_flag_value_N  95814_value_value_ DNR  \
# ID
# 90000-____0                              0                       0
# 90001-____0                              0                       0
#
#              95814_value_value_ Detected  95814_value_value_ Not detected  \
# ID
# 90000-____0                            0                                0
# 90001-____0                            0                                0
#
#              96087_hilonormal_flag_value_N  96087_value_value_ DNR
# ID
# 90000-____0                              0                       0
# 90001-____0                              0                       0
#
# [2 rows x 9773 columns]

# %%
sdf = df_features.astype(pd.SparseDtype(int, fill_value=0))
X_all = sparse.COO(sdf.sparse.to_coo())

# %%
sparse.save_npz('sample_output/out_labs/X_all.npz', X_all)
df_time_series[[]].to_csv('sample_output/out_labs/X_all.IDs.csv')

# %%
X_all.density
# Out:
# 0.00020464545175483476
