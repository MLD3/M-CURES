# %%
import joblib
import pandas as pd
import numpy as np
import sparse
import json

# %% [markdown]
# ### Vitals

# %%
df_time_series = joblib.load('sample_output/out_vitals/df_time_series.joblib')
discretization_bins = json.load(open('metadata/out_vitals/discretization.json', 'r'))
feature_names = json.load(open('metadata/out_vitals/X_all.feature_names.json', 'r'))
len(discretization_bins)
# Out:
# 30

# %%
cols_useful = list(discretization_bins.keys())

# %%
df_time_series = df_time_series[cols_useful]

# %%
df_time_series
# Out:
#             respiratoryrate_mask heartrate_mask temperature_mask sbp_mask  \
# 90000-____0                 True           True             True     True
# 90000-____1                 True           True             True     True
# 90001-____0                 True           True             True     True
#
#             dbp_mask spo2_mask respiratoryrate_value heartrate_value  \
# 90000-____0     True     False                    18             110
# 90000-____1     True     False                    20             117
# 90001-____0    False      True                    20             117
#
#             temperature_value sbp_value dbp_value spo2_value  \
# 90000-____0             101.3        92        66        NaN
# 90000-____1               100        92        60        NaN
# 90001-____0               100        92       NaN         98
#
#             respiratoryrate_min respiratoryrate_max respiratoryrate_mean  \
# 90000-____0                  18                  18                   18
# 90000-____1                  20                  20                   20
# 90001-____0                  20                  20                   20
#
#             heartrate_min heartrate_max heartrate_mean temperature_min  \
# 90000-____0           110           117          113.5           101.3
# 90000-____1           117           117            117             100
# 90001-____0           117           117            117             100
#
#             temperature_max temperature_mean sbp_min sbp_max sbp_mean dbp_min  \
# 90000-____0           101.3            101.3      92      92       92      66
# 90000-____1             100              100      92      92       92      60
# 90001-____0             100              100      92      92       92     NaN
#
#             dbp_max dbp_mean spo2_min spo2_max spo2_mean
# 90000-____0      66       66      NaN      NaN       NaN
# 90000-____1      60       60      NaN      NaN       NaN
# 90001-____0     NaN      NaN       98       98        98

# %%
from steps_2 import *
from helpers import *

# %%
df = df_time_series

# %% [raw]
# df_by_cols = [df[col] for col in df.columns]
# out_0 = [smart_qcut_bins(x, discretization_bins[x.name]) for x in tqdm(df_by_cols)]
# cols_data, dis_bins = zip(*out_0)
# out = [dummify(z) for z in tqdm(cols_data)]

# %%
pool = multiprocessing.Pool(multiprocessing.cpu_count())
out_0 = list(tqdm(pool.imap_unordered(
    smart_qcut_bins,
    [(df[col], discretization_bins[col]) for col in df.columns]), total=len(df.columns)
))
cols_data, dis_bins = zip(*out_0)
out = list(tqdm(pool.imap_unordered(dummify, cols_data), total=len(df.columns)
))
pool.close()
pool.join()
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 440.22it/s]
# 100%|██████████| 30/30 [00:00<00:00, 768.74it/s]

# %%
df_features = pd.concat(out, axis=1).sort_index(axis=1)

# %%
# Drop any values='missing' for now
df_features = df_features.loc[:, [col for col in df_features.columns if 'missing' not in col]]

# %%
# Make sure same features
set(df_features.columns) <= set(feature_names)
# Out:
# True

# %%
df_features = df_features.reindex(columns=feature_names, fill_value=0)

# %%
df_features
# Out:
#              dbp_mask_0.0  dbp_mask_1.0  dbp_max_(-0.001, 59.0]  \
# 90000-____0             0             1                       0
# 90000-____1             0             1                       0
# 90001-____0             1             0                       0
#
#              dbp_max_(59.0, 65.0]  dbp_max_(65.0, 72.0]  dbp_max_(72.0, 80.0]  \
# 90000-____0                     0                     1                     0
# 90000-____1                     1                     0                     0
# 90001-____0                     0                     0                     0
#
#              dbp_max_(80.0, 344.0]  dbp_mean_(-0.001, 57.0]  \
# 90000-____0                      0                        0
# 90000-____1                      0                        0
# 90001-____0                      0                        0
#
#              dbp_mean_(57.0, 63.0]  dbp_mean_(63.0, 69.0]  \
# 90000-____0                      0                      1
# 90000-____1                      1                      0
# 90001-____0                      0                      0
#
#              dbp_mean_(69.0, 77.0]  dbp_mean_(77.0, 164.333]  \
# 90000-____0                      0                         0
# 90000-____1                      0                         0
# 90001-____0                      0                         0
#
#              dbp_min_(-8.001, 55.0]  dbp_min_(55.0, 60.0]  \
# 90000-____0                       0                     0
# 90000-____1                       0                     1
# 90001-____0                       0                     0
#
#              dbp_min_(60.0, 67.0]  dbp_min_(67.0, 75.0]  \
# 90000-____0                     1                     0
# 90000-____1                     0                     0
# 90001-____0                     0                     0
#
#              dbp_min_(75.0, 154.0]  dbp_value_(-8.001, 57.0]  \
# 90000-____0                      0                         0
# 90000-____1                      0                         0
# 90001-____0                      0                         0
#
#              dbp_value_(57.0, 63.0]  dbp_value_(63.0, 69.0]  \
# 90000-____0                       0                       1
# 90000-____1                       1                       0
# 90001-____0                       0                       0
#
#              dbp_value_(69.0, 77.0]  dbp_value_(77.0, 344.0]  \
# 90000-____0                       0                        0
# 90000-____1                       0                        0
# 90001-____0                       0                        0
#
#              heartrate_mask_0.0  heartrate_mask_1.0  \
# 90000-____0                   0                   1
# 90000-____1                   0                   1
# 90001-____0                   0                   1
#
#              heartrate_max_(-0.001, 71.0]  heartrate_max_(101.0, 500.0]  \
# 90000-____0                             0                             1
# 90000-____1                             0                             1
# 90001-____0                             0                             1
#
#              heartrate_max_(71.0, 81.0]  heartrate_max_(81.0, 90.0]  \
# 90000-____0                           0                           0
# 90000-____1                           0                           0
# 90001-____0                           0                           0
#
#              heartrate_max_(90.0, 101.0]  heartrate_mean_(-0.001, 69.5]  \
# 90000-____0                            0                              0
# 90000-____1                            0                              0
# 90001-____0                            0                              0
#
#              heartrate_mean_(69.5, 78.667]  heartrate_mean_(78.667, 87.0]  \
# 90000-____0                              0                              0
# 90000-____1                              0                              0
# 90001-____0                              0                              0
#
#              heartrate_mean_(87.0, 97.5]  heartrate_mean_(97.5, 406.0]  \
# 90000-____0                            0                             1
# 90000-____1                            0                             1
# 90001-____0                            0                             1
#
#              heartrate_min_(-0.001, 67.0]  heartrate_min_(67.0, 76.0]  \
# 90000-____0                             0                           0
# 90000-____1                             0                           0
# 90001-____0                             0                           0
#
#              heartrate_min_(76.0, 84.0]  heartrate_min_(84.0, 95.0]  \
# 90000-____0                           0                           0
# 90000-____1                           0                           0
# 90001-____0                           0                           0
#
#              heartrate_min_(95.0, 406.0]  heartrate_value_(-0.001, 69.0]  \
# 90000-____0                            1                               0
# 90000-____1                            1                               0
# 90001-____0                            1                               0
#
#              heartrate_value_(69.0, 78.0]  heartrate_value_(78.0, 87.0]  \
# 90000-____0                             0                             0
# 90000-____1                             0                             0
# 90001-____0                             0                             0
#
#              heartrate_value_(87.0, 98.0]  heartrate_value_(98.0, 440.0]  \
# 90000-____0                             0                              1
# 90000-____1                             0                              1
# 90001-____0                             0                              1
#
#              respiratoryrate_mask_0.0  respiratoryrate_mask_1.0  \
# 90000-____0                         0                         1
# 90000-____1                         0                         1
# 90001-____0                         0                         1
#
#              respiratoryrate_max_(-0.001, 16.0]  \
# 90000-____0                                   0
# 90000-____1                                   0
# 90001-____0                                   0
#
#              respiratoryrate_max_(16.0, 18.0]  \
# 90000-____0                                 1
# 90000-____1                                 0
# 90001-____0                                 0
#
#              respiratoryrate_max_(18.0, 22.0]  \
# 90000-____0                                 0
# 90000-____1                                 1
# 90001-____0                                 1
#
#              respiratoryrate_max_(22.0, 200.0]  ...  sbp_min_(141.0, 423.0]  \
# 90000-____0                                  0  ...                       0
# 90000-____1                                  0  ...                       0
# 90001-____0                                  0  ...                       0
#
#              sbp_value_(-0.001, 106.0]  sbp_value_(106.0, 118.0]  \
# 90000-____0                          1                         0
# 90000-____1                          1                         0
# 90001-____0                          1                         0
#
#              sbp_value_(118.0, 130.0]  sbp_value_(130.0, 145.0]  \
# 90000-____0                         0                         0
# 90000-____1                         0                         0
# 90001-____0                         0                         0
#
#              sbp_value_(145.0, 463.0]  spo2_mask_0.0  spo2_mask_1.0  \
# 90000-____0                         0              1              0
# 90000-____1                         0              1              0
# 90001-____0                         0              0              1
#
#              spo2_max_(-0.001, 94.0]  spo2_max_(94.0, 96.0]  \
# 90000-____0                        0                      0
# 90000-____1                        0                      0
# 90001-____0                        0                      0
#
#              spo2_max_(96.0, 97.0]  spo2_max_(97.0, 99.0]  \
# 90000-____0                      0                      0
# 90000-____1                      0                      0
# 90001-____0                      0                      1
#
#              spo2_max_(99.0, 100.0]  spo2_mean_(-0.001, 94.0]  \
# 90000-____0                       0                         0
# 90000-____1                       0                         0
# 90001-____0                       0                         0
#
#              spo2_mean_(94.0, 95.0]  spo2_mean_(95.0, 96.667]  \
# 90000-____0                       0                         0
# 90000-____1                       0                         0
# 90001-____0                       0                         0
#
#              spo2_mean_(96.667, 98.0]  spo2_mean_(98.0, 100.0]  \
# 90000-____0                         0                        0
# 90000-____1                         0                        0
# 90001-____0                         1                        0
#
#              spo2_min_(-0.001, 93.0]  spo2_min_(93.0, 95.0]  \
# 90000-____0                        0                      0
# 90000-____1                        0                      0
# 90001-____0                        0                      0
#
#              spo2_min_(95.0, 96.0]  spo2_min_(96.0, 98.0]  \
# 90000-____0                      0                      0
# 90000-____1                      0                      0
# 90001-____0                      0                      1
#
#              spo2_min_(98.0, 100.0]  spo2_value_(-0.001, 94.0]  \
# 90000-____0                       0                          0
# 90000-____1                       0                          0
# 90001-____0                       0                          0
#
#              spo2_value_(94.0, 95.0]  spo2_value_(95.0, 97.0]  \
# 90000-____0                        0                        0
# 90000-____1                        0                        0
# 90001-____0                        0                        0
#
#              spo2_value_(97.0, 98.0]  spo2_value_(98.0, 100.0]  \
# 90000-____0                        0                         0
# 90000-____1                        0                         0
# 90001-____0                        1                         0
#
#              temperature_mask_0.0  temperature_mask_1.0  \
# 90000-____0                     0                     1
# 90000-____1                     0                     1
# 90001-____0                     0                     1
#
#              temperature_max_(0.999, 97.7]  temperature_max_(97.7, 98.1]  \
# 90000-____0                              0                             0
# 90000-____1                              0                             0
# 90001-____0                              0                             0
#
#              temperature_max_(98.1, 98.3]  temperature_max_(98.3, 98.8]  \
# 90000-____0                             0                             0
# 90000-____1                             0                             0
# 90001-____0                             0                             0
#
#              temperature_max_(98.8, 146.8]  temperature_mean_(0.999, 97.7]  \
# 90000-____0                              1                               0
# 90000-____1                              1                               0
# 90001-____0                              1                               0
#
#              temperature_mean_(97.7, 98.1]  temperature_mean_(98.1, 98.3]  \
# 90000-____0                              0                              0
# 90000-____1                              0                              0
# 90001-____0                              0                              0
#
#              temperature_mean_(98.3, 98.7]  temperature_mean_(98.7, 136.4]  \
# 90000-____0                              0                               1
# 90000-____1                              0                               1
# 90001-____0                              0                               1
#
#              temperature_min_(0.999, 97.7]  temperature_min_(97.7, 98.0]  \
# 90000-____0                              0                             0
# 90000-____1                              0                             0
# 90001-____0                              0                             0
#
#              temperature_min_(98.0, 98.2]  temperature_min_(98.2, 98.6]  \
# 90000-____0                             0                             0
# 90000-____1                             0                             0
# 90001-____0                             0                             0
#
#              temperature_min_(98.6, 136.4]  temperature_value_(0.999, 97.7]  \
# 90000-____0                              1                                0
# 90000-____1                              1                                0
# 90001-____0                              1                                0
#
#              temperature_value_(97.7, 98.1]  temperature_value_(98.1, 98.3]  \
# 90000-____0                               0                               0
# 90000-____1                               0                               0
# 90001-____0                               0                               0
#
#              temperature_value_(98.3, 98.7]  temperature_value_(98.7, 146.8]
# 90000-____0                               0                                1
# 90000-____1                               0                                1
# 90001-____0                               0                                1
#
# [3 rows x 129 columns]

# %%
sdf = df_features.astype(pd.SparseDtype(int, fill_value=0))
X_all = sparse.COO(sdf.sparse.to_coo())

# %%
sparse.save_npz('sample_output/out_vitals/X_all.npz', X_all)
df_time_series[[]].to_csv('sample_output/out_vitals/X_all.IDs.csv')
# json.dump(list(X_all_feature_names), open('out_meds/X_all.feature_names.json', 'w'), sort_keys=True)
# json.dump(discretization_bins, open('out_meds/discretization.json', 'w'))
